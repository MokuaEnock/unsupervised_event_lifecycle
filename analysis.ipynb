# %%
import pandas as pd

# %%
# import data
file_url = "./data/raw/kenyan_news_features_baseline_part_1.parquet"

# %%
data_df = pd.read_parquet(file_url)

# %%
data_df.head()
# Out:
#   article_id  article_word_count  article_char_count  sentence_count  \
# 0     124954                 461                2904              18
# 1     124953                 497                3651              21
# 2     124951                 564                3568              17
# 3     124950                 467                3069              16
# 4     124949                 389                2429              15
#
#    avg_sentence_length  estimated_reading_time_minutes  publish_year  \
# 0                25.61                               3        2026.0
# 1                23.67                               3        2026.0
# 2                33.18                               3        2026.0
# 3                29.19                               3        2026.0
# 4                25.93                               2        2026.0
#
#    publish_month  publish_day  publish_hour  ... is_breaking has_multimedia  \
# ...
